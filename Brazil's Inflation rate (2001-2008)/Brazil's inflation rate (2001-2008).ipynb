# %%
import basedosdados as bd

# Para carregar o dado direto no pandas
import pandas as pd
df = bd.read_table(dataset_id='br_ibge_ipca15',
table_id='mes_brasil',
billing_project_id="bustling-walker-349821")
# Out:
# Downloading: 100%|████████████████████████████████████████████████████████████████| 264/264 [00:00<00:00, 681.07rows/s]

# %%
print (df)
# Out:
#       ano  mes   indice  variacao_mensal  variacao_trimestral  \
# 0    2000    5  1584.32             0.09                 0.65
# 1    2000    6  1585.59             0.08                 0.64
# 2    2000    7  1597.96             0.78                 0.95
# 3    2000    8  1629.76             1.99                 2.87
# 4    2000    9  1637.09             0.45                 3.25
# ..    ...  ...      ...              ...                  ...
# 259  2021   12  5992.99             0.78                 3.18
# 260  2022    1  6027.75             0.58                 2.55
# 261  2022    2  6087.42             0.99                 2.37
# 262  2022    3  6145.25             0.95                 2.54
# 263  2022    4  6251.56             1.73                 3.71
#
#      variacao_semestral  variacao_anual  variacao_doze_meses
# 0                  2.57            1.65                 6.57
# 1                  1.73            1.73                 6.68
# 2                  1.86            2.52                 6.67
# 3                  3.54            4.56                 7.92
# 4                  3.91            5.03                 7.90
# ..                  ...             ...                  ...
# 259                6.05           10.42                10.42
# 260                5.90            0.58                10.20
# 261                6.00            1.58                10.76
# 262                5.80            2.54                10.79
# 263                6.36            4.31                12.03
#
# [264 rows x 8 columns]

# %%
df.rename(columns={'mes':'mês', 'indice':'índice', 'variacao_mensal':'variação mensal'}, inplace = True)

# %%
df.head(10)
# Out:
#     ano  mês   índice  variação mensal  variacao_trimestral  \
# 0  2000    5  1584.32             0.09                 0.65
# 1  2000    6  1585.59             0.08                 0.64
# 2  2000    7  1597.96             0.78                 0.95
# 3  2000    8  1629.76             1.99                 2.87
# 4  2000    9  1637.09             0.45                 3.25
# 5  2000   10  1640.04             0.18                 2.63
# 6  2000   11  1642.83             0.17                 0.80
# 7  2000   12  1652.69             0.60                 0.95
# 8  2001    1  1663.10             0.63                 1.41
# 9  2001    2  1671.42             0.50                 1.74
#
#    variacao_semestral  variacao_anual  variacao_doze_meses
# 0                2.57            1.65                 6.57
# 1                1.73            1.73                 6.68
# 2                1.86            2.52                 6.67
# 3                3.54            4.56                 7.92
# 4                3.91            5.03                 7.90
# 5                3.61            5.22                 7.23
# 6                3.69            5.40                 6.36
# 7                4.23            6.04                 6.04
# 8                4.08            0.63                 6.01
# 9                2.56            1.13                 6.18

# %%
df.loc[:, 'ano':'índice']
# Out:
#       ano  mês   índice
# 0    2000    5  1584.32
# 1    2000    6  1585.59
# 2    2000    7  1597.96
# 3    2000    8  1629.76
# 4    2000    9  1637.09
# ..    ...  ...      ...
# 259  2021   12  5992.99
# 260  2022    1  6027.75
# 261  2022    2  6087.42
# 262  2022    3  6145.25
# 263  2022    4  6251.56
#
# [264 rows x 3 columns]

# %%
inf2=df.loc[:,['ano', 'mês', 'índice', 'variação mensal', 'variacao_doze_meses']]

# %%
print (inf2)
# Out:
#       ano  mês   índice  variação mensal  variacao_doze_meses
# 0    2000    5  1584.32             0.09                 6.57
# 1    2000    6  1585.59             0.08                 6.68
# 2    2000    7  1597.96             0.78                 6.67
# 3    2000    8  1629.76             1.99                 7.92
# 4    2000    9  1637.09             0.45                 7.90
# ..    ...  ...      ...              ...                  ...
# 259  2021   12  5992.99             0.78                10.42
# 260  2022    1  6027.75             0.58                10.20
# 261  2022    2  6087.42             0.99                10.76
# 262  2022    3  6145.25             0.95                10.79
# 263  2022    4  6251.56             1.73                12.03
#
# [264 rows x 5 columns]

# %%
inf01a08=inf2.loc[8:100]

# %%
df.loc[1:40]
# Out:
#      ano  mês   índice  variação mensal  variacao_trimestral  \
# 1   2000    6  1585.59             0.08                 0.64
# 2   2000    7  1597.96             0.78                 0.95
# 3   2000    8  1629.76             1.99                 2.87
# 4   2000    9  1637.09             0.45                 3.25
# 5   2000   10  1640.04             0.18                 2.63
# 6   2000   11  1642.83             0.17                 0.80
# 7   2000   12  1652.69             0.60                 0.95
# 8   2001    1  1663.10             0.63                 1.41
# 9   2001    2  1671.42             0.50                 1.74
# 10  2001    3  1677.44             0.36                 1.50
# 11  2001    4  1685.83             0.50                 1.37
# 12  2001    5  1694.09             0.49                 1.36
# 13  2001    6  1700.53             0.38                 1.38
# 14  2001    7  1716.51             0.94                 1.82
# 15  2001    8  1736.76             1.18                 2.52
# 16  2001    9  1743.36             0.38                 2.52
# 17  2001   10  1749.81             0.37                 1.94
# 18  2001   11  1767.13             0.99                 1.75
# 19  2001   12  1776.85             0.55                 1.92
# 20  2002    1  1787.87             0.62                 2.18
# 21  2002    2  1795.74             0.44                 1.62
# 22  2002    3  1802.92             0.40                 1.47
# 23  2002    4  1816.98             0.78                 1.63
# 24  2002    5  1824.61             0.42                 1.61
# 25  2002    6  1830.63             0.33                 1.54
# 26  2002    7  1844.73             0.77                 1.53
# 27  2002    8  1863.18             1.00                 2.11
# 28  2002    9  1874.73             0.62                 2.41
# 29  2002   10  1891.60             0.90                 2.54
# 30  2002   11  1930.95             2.08                 3.64
# 31  2002   12  1989.84             3.05                 6.14
# 32  2003    1  2029.24             1.98                 7.28
# 33  2003    2  2073.68             2.19                 7.39
# 34  2003    3  2097.32             1.14                 5.40
# 35  2003    4  2121.23             1.14                 4.53
# 36  2003    5  2139.26             0.85                 3.16
# 37  2003    6  2143.97             0.22                 2.22
# 38  2003    7  2140.11            -0.18                 0.89
# 39  2003    8  2145.89             0.27                 0.31
# 40  2003    9  2158.12             0.57                 0.66
#
#     variacao_semestral  variacao_anual  variacao_doze_meses
# 1                 1.73            1.73                 6.68
# 2                 1.86            2.52                 6.67
# 3                 3.54            4.56                 7.92
# 4                 3.91            5.03                 7.90
# 5                 3.61            5.22                 7.23
# 6                 3.69            5.40                 6.36
# 7                 4.23            6.04                 6.04
# 8                 4.08            0.63                 6.01
# 9                 2.56            1.13                 6.18
# 10                2.46            1.50                 6.47
# 11                2.79            2.01                 6.50
# 12                3.12            2.51                 6.93
# 13                2.89            2.89                 7.25
# 14                3.21            3.86                 7.42
# 15                3.91            5.09                 6.57
# 16                3.93            5.49                 6.49
# 17                3.80            5.88                 6.69
# 18                4.31            6.92                 7.57
# 19                4.49            7.51                 7.51
# 20                4.16            0.62                 7.50
# 21                3.40            1.06                 7.44
# 22                3.42            1.47                 7.48
# 23                3.84            2.26                 7.78
# 24                3.25            2.69                 7.70
# 25                3.03            3.03                 7.65
# 26                3.18            3.82                 7.47
# 27                3.76            4.86                 7.28
# 28                3.98            5.51                 7.54
# 29                4.11            6.46                 8.10
# 30                5.83            8.67                 9.27
# 31                8.70           11.99                11.99
# 32               10.00            1.98                13.50
# 33               11.30            4.21                15.48
# 34               11.87            5.40                16.33
# 35               12.14            6.60                16.74
# 36               10.79            7.51                17.24
# 37                7.75            7.75                17.12
# 38                5.46            7.55                16.01
# 39                3.48            7.84                15.17
# 40                2.90            8.46                15.12

# %%
inf01a08.head()
# Out:
#      ano  mês   índice  variação mensal  variacao_doze_meses
# 8   2001    1  1663.10             0.63                 6.01
# 9   2001    2  1671.42             0.50                 6.18
# 10  2001    3  1677.44             0.36                 6.47
# 11  2001    4  1685.83             0.50                 6.50
# 12  2001    5  1694.09             0.49                 6.93

# %%
inf01a08.describe()
# Out:
#                ano        mês       índice  variação mensal  \
# count    93.000000  93.000000    93.000000        93.000000
# mean   2004.387097   6.354839  2274.383226         0.572366
# std       2.250760   3.425116   343.766659         0.472740
# min    2001.000000   1.000000  1663.100000        -0.180000
# 25%    2002.000000   3.000000  1989.840000         0.290000
# 50%    2004.000000   6.000000  2331.210000         0.490000
# 75%    2006.000000   9.000000  2544.250000         0.700000
# max    2008.000000  12.000000  2807.180000         3.050000
#
#        variacao_doze_meses
# count            93.000000
# mean              7.137957
# std               3.537770
# min               2.910000
# 25%               4.890000
# 50%               6.500000
# 75%               7.540000
# max              17.240000

# %%
a = inf01a08['ano']
i = inf01a08['índice']
j = inf01a08['variacao_doze_meses']
v = inf01a08['variação mensal']
y = [2001, 2002, 2003, 2004]

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use('seaborn-darkgrid')

# %%
plt.figure (figsize=(8,4))
plt.bar (a, j, color='brown')
plt.ylabel ('variação (%)')
plt.xlabel('ano')
plt.title ('Variação anual do IPCA (%) do Brasil')
plt.style.library['seaborn-darkgrid']
plt.axis ([2000, 2009, 1, 18])

plt.show()

# %%
plt.figure (figsize=(10,5))
plt.plot (a,j, color='grey')

# %%
plt.plot(j,j**2)

# %%
yy=[int(i) for i in y]
print (yy)
# Out:
# [2001, 2002, 2003, 2004]

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
hist(v)

# %%
import matplotlib.pyplot as plt
plt.plot?

# %%
import pandas as pd
import seaborn as sns

# %%
sns.relplot(x='variacao_anual', y='variacao_doze_meses', data=df, hue='variacao_anual')

# %%
plt.plot(j)

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('seaborn-darkgrid')

# %%
# !pip install python-bcb
# Out:
# Collecting python-bcb
#   Downloading python_bcb-0.1.7-py3-none-any.whl (13 kB)
# Collecting httpx
#   Downloading httpx-0.22.0-py3-none-any.whl (84 kB)
#      -------------------------------------- 84.2/84.2 kB 591.5 kB/s eta 0:00:00
# Requirement already satisfied: certifi in c:\users\pc\appdata\roaming\python\python310\site-packages (from httpx->python-bcb) (2021.10.8)
# Requirement already satisfied: charset-normalizer in c:\users\pc\appdata\roaming\python\python310\site-packages (from httpx->python-bcb) (2.0.12)
# Collecting httpcore<0.15.0,>=0.14.5
#   Downloading httpcore-0.14.7-py3-none-any.whl (68 kB)
#      ---------------------------------------- 68.3/68.3 kB 1.9 MB/s eta 0:00:00
# Collecting sniffio
#   Downloading sniffio-1.2.0-py3-none-any.whl (10 kB)
# Collecting rfc3986[idna2008]<2,>=1.3
#   Downloading rfc3986-1.5.0-py2.py3-none-any.whl (31 kB)
# Collecting anyio==3.*
#   Downloading anyio-3.6.1-py3-none-any.whl (80 kB)
#      ---------------------------------------- 80.6/80.6 kB 2.3 MB/s eta 0:00:00
# Collecting h11<0.13,>=0.11
#   Downloading h11-0.12.0-py3-none-any.whl (54 kB)
#      ---------------------------------------- 54.9/54.9 kB 2.8 MB/s eta 0:00:00
# Requirement already satisfied: idna>=2.8 in c:\users\pc\appdata\roaming\python\python310\site-packages (from anyio==3.*->httpcore<0.15.0,>=0.14.5->httpx->python-bcb) (3.3)
# Installing collected packages: rfc3986, sniffio, h11, anyio, httpcore, httpx, python-bcb
# Successfully installed anyio-3.6.1 h11-0.12.0 httpcore-0.14.7 httpx-0.22.0 python-bcb-0.1.7 rfc3986-1.5.0 sniffio-1.2.0
#   WARNING: The script httpx.exe is installed in 'C:\Users\PC\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from bcb import sgs
selic = sgs.get({'selic':432}, start = '2010-01-01')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_7480/3780931838.py in <module>
# ----> 1 from bcb import sgs
#       2 selic = sgs.get({'selic':432}, start = '2010-01-01')
#
# ModuleNotFoundError: No module named 'bcb'
